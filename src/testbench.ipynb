# %%
import http.client

conn = http.client.HTTPSConnection("cricbuzz-cricket.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "5f7c2b2bd4mshd83fef6323ec7e5p1ec4abjsnf143770be8bf",
    'x-rapidapi-host': "cricbuzz-cricket.p.rapidapi.com"
}

conn.request("GET", "/matches/v1/live", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {
#   "typeMatches": [{
#     "matchType": "International",
#     "seriesMatches": [{
#       "seriesAdWrapper": {
#         "seriesId": 8786,
#         "seriesName": "India tour of England, 2025",
#         "matches": [{
#           "matchInfo": {
#             "matchId": 105770,
#             "seriesId": 8786,
#             "seriesName": "India tour of England, 2025",
#             "matchDesc": "2nd Test",
#             "matchFormat": "TEST",
#             "startDate": "1751450400000",
#             "endDate": "1751821200000",
#             "state": "In Progress",
#             "status": "Day 5: 1st Session - England need 479 runs",
#             "team1": {
#               "teamId": 2,
#               "teamName": "India",
#               "teamSName": "IND",
#               "imageId": 719031
#             },
#             "team2": {
#               "teamId": 9,
#               "teamName": "England",
#               "teamSName": "ENG",
#               "imageId": 172123
# ...
